# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import time

# Sample text
text = "NLP is very interesting and helps computers understand human language."

# Start performance timing
start_time = time.time()

# 1️⃣ Tokenization
tokens = word_tokenize(text)
print("Tokens:", tokens)

# 2️⃣ Stopword Removal
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in tokens if word.lower() not in stop_words]
print("\nAfter Stopword Removal:", filtered_words)

# 3️⃣ Stemming
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]
print("\nStemmed Words:", stemmed_words)

# 4️⃣ Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
print("\nLemmatized Words:", lemmatized_words)

# End performance timing
end_time = time.time()

print("\nProcessing Time:", end_time - start_time, "seconds")
# Out:
# Tokens: ['NLP', 'is', 'very', 'interesting', 'and', 'helps', 'computers', 'understand', 'human', 'language', '.']
#
# After Stopword Removal: ['NLP', 'interesting', 'helps', 'computers', 'understand', 'human', 'language', '.']
#
# Stemmed Words: ['nlp', 'interest', 'help', 'comput', 'understand', 'human', 'languag', '.']
#
# Lemmatized Words: ['NLP', 'interesting', 'help', 'computer', 'understand', 'human', 'language', '.']
#
# Processing Time: 2.109856128692627 seconds
